# %%
from stock import Stock
# Out:
# Imports Loaded

# %%
aapl = Stock("AAPL")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aapl.preprocess()
aapl.set_model()
aapl.train_model()
predictions, rmse = aapl.predict()
# Out:
# 9829/9829 [==============================] - 233s 24ms/step - loss: 1.1732e-04

# %%
predictions
# Out:
# array([[ 71.152   ],
#        [ 72.62561 ],
#        [ 72.38748 ],
#        [ 71.55035 ],
#        [ 68.506165],
#        [ 68.709404],
#        [ 68.2283  ],
#        [ 64.89455 ],
#        [ 65.98268 ],
#        [ 63.273518],
#        [ 62.43935 ],
#        [ 61.57715 ],
#        [ 60.89016 ],
#        [ 58.814606],
#        [ 56.94732 ],
#        [ 58.448235],
#        [ 59.566753],
#        [ 61.464024],
#        [ 61.341244],
#        [ 61.710854],
#        [ 61.908417],
#        [ 60.5227  ],
#        [ 60.013817],
#        [ 59.514565],
#        [ 61.58743 ],
#        [ 62.72528 ],
#        [ 63.8924  ],
#        [ 64.699715],
#        [ 65.642426],
#        [ 67.6797  ],
#        [ 68.631134],
#        [ 69.23021 ],
#        [ 69.08642 ],
#        [ 68.29275 ],
#        [ 66.88432 ],
#        [ 66.9495  ],
#        [ 67.11949 ],
#        [ 68.111   ],
#        [ 68.767334],
#        [ 68.544266],
#        [ 69.29412 ],
#        [ 70.49611 ],
#        [ 70.67195 ],
# ...

# %%
rmse
# Out:
# 6.763092075420834

# %%
aapl.get_all_data()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100323
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095089
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088110
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090291
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092908
# ...                ...         ...         ...         ...         ...
# 2022-03-18  160.509995  164.479996  159.759995  163.979996  163.979996
# 2022-03-21  163.509995  166.350006  163.009995  165.380005  165.380005
# 2022-03-22  165.509995  169.419998  164.910004  168.820007  168.820007
# 2022-03-23  167.990005  172.639999  167.649994  170.210007  170.210007
# 2022-03-24  171.059998  174.139999  170.210007  174.070007  174.070007
#
#                Volume
# Date
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# ...

# %%
aapl.plot_cp_hist()

# %%
aapl.plot_pred()
# Out:
# /Users/rayaq/Desktop/mini projects/stock_market_analysis_lstm/stock.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.valid['Predictions'] = self.predictions

# %%
s = Stock("RIVN")
s.preprocess()
s.set_model()
s.train_model()
predictions, rmse = s.predict()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 30/30 [==============================] - 2s 23ms/step - loss: 0.0064

# %%
rmse
# Out:
# 1.6846566014146465

# %%
s.get_all_data()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-11-10  106.750000  119.459999   95.199997  100.730003  100.730003
# 2021-11-11  114.625000  125.000000  108.010002  122.989998  122.989998
# 2021-11-12  128.645004  135.199997  125.250000  129.949997  129.949997
# 2021-11-15  130.800003  152.529999  127.510002  149.360001  149.360001
# 2021-11-16  163.800003  179.470001  153.779999  172.009995  172.009995
# ...                ...         ...         ...         ...         ...
# 2022-03-21   45.639999   46.549999   42.310001   43.560001   43.560001
# 2022-03-22   43.650002   48.299999   43.130001   46.930000   46.930000
# 2022-03-23   46.470001   48.000000   44.630001   45.869999   45.869999
# 2022-03-24   46.250000   48.700001   44.599998   48.660000   48.660000
# 2022-03-25   48.869999   49.099998   45.230000   46.160000   46.160000
#
#                Volume
# Date
# 2021-11-10  103679500
# 2021-11-11   83668200
# 2021-11-12   50636800
# ...

# %%
s.plot_cp_hist()

# %%
s.plot_pred()
# Out:
# /Users/rayaq/Desktop/mini projects/stock_market_analysis_lstm/stock.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.valid['Predictions'] = self.predictions

# %%
s.valid
# Out:
#                 Close  Predictions
# Date
# 2022-03-22  46.930000    45.410610
# 2022-03-23  45.869999    45.513611
# 2022-03-24  48.660000    45.680603
# 2022-03-25  46.160000    45.960232
